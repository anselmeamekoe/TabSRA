# %% [markdown]
# # Regression example using TabSRALinear: *Synthetic* 3 dataset
#
#
#    $$y  = (5x_1-5x_2)1_{x_5\le 0}+(5x_3-5x_4)1_{x_5> 0}$$

# %% [markdown]
# ## Librairies

# %%
import os, sys, time
import numpy as np
import pandas as pd

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import torch 
import torch.nn as nn
import torch.optim as optim

# %%
sys.path.append('../')
from SRAModels import TabSRALinear,LR
from utils import TrainRegressionModel,reset_seed_,Predict, load, save,LinearScaling

# %% [markdown]
# ## Data

# %%
np.random.seed(42)
x1 = np.random.normal(0,1,3*10000)
x2 = np.random.normal(0,1,3*10000)
x3 = np.random.normal(0,1,3*10000)
x4 = np.random.normal(0,1,3*10000)
x5 = np.random.normal(0,1,3*10000)
X = np.concatenate((x1.reshape(-1,1), x2.reshape(-1,1),x3.reshape(-1,1),x4.reshape(-1,1),x5.reshape(-1,1)  ),axis=1)

# %%
odd = (5*x1-5*x2)*(x5<=0) + (5*x3-5*x4)*(x5>0)
y_c = 1/(1+np.exp(-odd))
y = np.where(y_c>0.5, 1,0)
X_train_,X_test_,Y_train_,Y_test_ = train_test_split(X,odd,stratify =y , random_state=42)
n_features, n_classes = 5,1
len(Y_train_),len(Y_test_)
# Out:
# (22500, 7500)

# %%
feature_names = ['x1','x2','x3','x4','x5']
df_test = pd.DataFrame(X_test_,columns=feature_names)
df_test['y'] = Y_test_
df_test.head()
# Out:
#          x1        x2        x3        x4        x5          y
# 0 -0.615981 -0.905865  1.641829  0.600394  0.779350   5.207175
# 1  0.459180 -0.335791 -0.346584  1.266684 -1.742044   3.974853
# 2  0.328236  0.040834 -2.833473 -0.068043 -1.490514   1.437009
# 3 -0.890823  1.909281 -0.013401  0.773885 -0.426686 -14.000517
# 4 -0.861023  0.227261  0.054344 -0.107080  1.006329   0.807119

# %% [markdown]
# ## Model: LR (Linear Regression)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
train_set = torch.utils.data.TensorDataset(torch.Tensor(X_train_), torch.Tensor(Y_train_))
val_set = torch.utils.data.TensorDataset(torch.Tensor(X_test_), torch.Tensor(Y_test_))

# %%
## function to build the model
def buildLR(static_params):
    Model = LR(dim_input = static_params['dim_input'],
                   dim_output = static_params['dim_output'],
                   bias = static_params['bias'],
                   for_classif=False
                  )
    return Model

# %%
static_params_LR = {'dim_input':n_features, 'dim_output':n_classes, 'bias':True}

# %%
# %%time
reset_seed_(45)
SimpleLR = buildLR(static_params_LR)
save_model_dir= f'LR_Synthetic3'
SimpleLR = TrainRegressionModel(SimpleLR, 
                   train_set = train_set,
                   test_set=val_set,
                   save_path=save_model_dir,
                   device = device,
                   epochs= 100,
                   batch_size = 256,
                   lr = 0.5*1e-2,
                   eval_every = 5,
                   weight_decay = 0.0,
                   verbose=1,
                   load_best_eval=True
                   )
# Out:
# epoch = 0--rmse perf = 6.876037120819092
# epoch = 5--rmse perf = 5.299612522125244
# epoch = 10--rmse perf = 5.0552978515625
# epoch = 15--rmse perf = 5.043054580688477
# epoch = 20--rmse perf = 5.042910099029541
# epoch = 25--rmse perf = 5.042958736419678
# epoch = 30--rmse perf = 5.04299783706665
# epoch = 35--rmse perf = 5.042749881744385
# epoch = 40--rmse perf = 5.043017864227295
# epoch = 45--rmse perf = 5.042979717254639
# epoch = 50--rmse perf = 5.042929172515869
# epoch = 55--rmse perf = 5.042665481567383
# epoch = 60--rmse perf = 5.043076038360596
# epoch = 65--rmse perf = 5.04296875
# epoch = 70--rmse perf = 5.042609691619873
# epoch = 75--rmse perf = 5.042875289916992
# epoch = 80--rmse perf = 5.04315185546875
# epoch = 85--rmse perf = 5.042682647705078
# epoch = 90--rmse perf = 5.042680263519287
# epoch = 95--rmse perf = 5.042820930480957
# CPU times: user 16.6 s, sys: 591 ms, total: 17.2 s
# Wall time: 16.1 s

# %%
pred_tab_lr = Predict(SimpleLR,val_set[:][0],device=device)
rmse = np.sqrt(mean_squared_error(Y_test_, pred_tab_lr))
r2 = r2_score(Y_test_, pred_tab_lr) 
print(f"--RMSE perf = {rmse} -- r2 perf = {r2}")
# Out:
# --RMSE perf = 5.042609461402693 -- r2 perf = 0.4991680792159717

# %% [markdown]
# ## Model: TabSRALinear

# %%
## function to build the model
def buildTabSRA(config_opt,static_params):
    Model = TabSRALinear(dim_input = static_params['dim_input'],
                   dim_output = static_params['dim_output'],
                   dim_head = config_opt['dim_head'],
                   get_attention = static_params['get_attention'],
                   dropout_rate = config_opt['dropout_rate'],
                   activation = static_params['activation'],
                   bias = static_params['bias'],
                   s =  LinearScaling(scale = config_opt['dim_head']**-0.5),
                   for_classif=False
                  )
    return Model

# %%
## The hyperparameters are already optimized (using optuna) 
config_opt = {'lr': 1e-2, 'dropout_rate': 0.0, 'dim_head': 8, 'epochs': 160, 'weight_decay': 1e-6, 'batch_size': 768}
static_params = {'dim_input':n_features, 'dim_output':n_classes,'get_attention':True, 'activation':nn.ReLU(), 'bias':False}

# %%
# %%time
reset_seed_(42)
Model = buildTabSRA(config_opt,static_params)
save_model_dir= f'TabSRALinear_Synthetic3'
Model = TrainRegressionModel(Model, 
                   train_set = train_set,
                   test_set=val_set,
                   save_path=save_model_dir,
                   device = device,
                   epochs= config_opt['epochs'],
                   batch_size = config_opt['batch_size'],
                   lr = config_opt['lr'],
                   eval_every = 5,
                   weight_decay = config_opt['weight_decay'],
                   verbose=1,
                   load_best_eval=True
                   )
# Out:
# epoch = 0--rmse perf = 6.507522106170654
# epoch = 5--rmse perf = 4.722599983215332
# epoch = 10--rmse perf = 3.4804437160491943
# epoch = 15--rmse perf = 3.0078487396240234
# epoch = 20--rmse perf = 2.7814269065856934
# epoch = 25--rmse perf = 2.191732883453369
# epoch = 30--rmse perf = 1.9000459909439087
# epoch = 35--rmse perf = 1.8453086614608765
# epoch = 40--rmse perf = 1.7616018056869507
# epoch = 45--rmse perf = 1.6819323301315308
# epoch = 50--rmse perf = 1.5935912132263184
# epoch = 55--rmse perf = 1.5102094411849976
# epoch = 60--rmse perf = 1.3394999504089355
# epoch = 65--rmse perf = 1.0649223327636719
# epoch = 70--rmse perf = 0.7894779443740845
# epoch = 75--rmse perf = 0.634148359298706
# epoch = 80--rmse perf = 0.613721489906311
# epoch = 85--rmse perf = 0.5352481007575989
# epoch = 90--rmse perf = 0.5610854029655457
# epoch = 95--rmse perf = 0.7653432488441467
# epoch = 100--rmse perf = 0.5630683302879333
# epoch = 105--rmse perf = 0.5042901039123535
# epoch = 110--rmse perf = 0.5022802948951721
# epoch = 115--rmse perf = 0.45937567949295044
# epoch = 120--rmse perf = 0.5657488703727722
# epoch = 125--rmse perf = 0.4103279709815979
# epoch = 130--rmse perf = 0.6026252508163452
# epoch = 135--rmse perf = 0.4627631604671478
# epoch = 140--rmse perf = 0.5379854440689087
# epoch = 145--rmse perf = 0.4381186366081238
# epoch = 150--rmse perf = 0.5087437033653259
# epoch = 155--rmse perf = 0.37512069940567017
# CPU times: user 26.1 s, sys: 194 ms, total: 26.3 s
# Wall time: 26.2 s

# %%
# Inference on the test set. the Predict function will return the ouptut scores and the attention weights as Model.get_attention is True
att,pred_tabsra = Predict(Model,val_set[:][0],device=device)

rmse_tabsra = np.sqrt(mean_squared_error(Y_test_, pred_tabsra))
r2_tabsra = r2_score(Y_test_, pred_tabsra) 
print(f"--RMSE perf = {rmse_tabsra} -- r2 perf = {r2_tabsra}")
# Out:
# --RMSE perf = 0.37512070997404334 -- r2 perf = 0.9972284455460778

# %%
Model.classifier.weight
# Out:
# Parameter containing:
# tensor([[ 4.9963, -4.9966,  5.7022, -4.9926,  6.5851]], device='cuda:0',
#        requires_grad=True)

# %% [markdown]
# ## Model: XGBoost

# %%
from xgboost import XGBRegressor
# Out:
# /home/kodjo/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
def buildXGBoost(config_opt,static_params):
    config_opt.update(static_params)
    model_xgb = XGBRegressor(**config_opt)
    return model_xgb

# %%
### These parameters are optimized using 30 trials with optuna (bayesian optimization)
config_opt_xgb = {
              'eta': 0.03425616464106714,
              'max_depth': 5,
              'colsample_bytree': 0.8,
              'subsample': 0.7,
              'n_estimators': 1100,
              'min_child_weight':56

              }
static_params_xgb = {
                 'random_state':45,
                 'n_jobs': -1,
}

# %%
# %%time
model_xgb = buildXGBoost(config_opt=config_opt_xgb,static_params=static_params_xgb)
eval_set = [(X_test_, Y_test_)]
model_xgb.fit(X_train_, Y_train_, eval_metric=['rmse'], eval_set=eval_set, verbose=1)
# Out:
# [0]	validation_0-rmse:6.98450
# [1]	validation_0-rmse:6.83646
# [2]	validation_0-rmse:6.69133
# [3]	validation_0-rmse:6.53541
# [4]	validation_0-rmse:6.45900
# [5]	validation_0-rmse:6.31099
# [6]	validation_0-rmse:6.17516
# [7]	validation_0-rmse:6.03997
# [8]	validation_0-rmse:5.97170
# [9]	validation_0-rmse:5.84318
# [10]	validation_0-rmse:5.71118
# [11]	validation_0-rmse:5.58313
# [12]	validation_0-rmse:5.46127
# [13]	validation_0-rmse:5.40268
# [14]	validation_0-rmse:5.34586
# [15]	validation_0-rmse:5.23512
# [16]	validation_0-rmse:5.18239
# [17]	validation_0-rmse:5.13137
# [18]	validation_0-rmse:5.01477
# [19]	validation_0-rmse:4.91118
# [20]	validation_0-rmse:4.79910
# [21]	validation_0-rmse:4.70381
# [22]	validation_0-rmse:4.60087
# [105]	validation_0-rmse:1.23108
# [106]	validation_0-rmse:1.21057
# [107]	validation_0-rmse:1.19532
# [108]	validation_0-rmse:1.17658
# [109]	validation_0-rmse:1.15755
# [110]	validation_0-rmse:1.14109
# [111]	validation_0-rmse:1.13009
# [112]	validation_0-rmse:1.11379
# [113]	validation_0-rmse:1.10792
# [114]	validation_0-rmse:1.10514
# [115]	validation_0-rmse:1.08793
# [116]	validation_0-rmse:1.07075
# [117]	validation_0-rmse:1.05423
# [118]	validation_0-rmse:1.03883
# [119]	validation_0-rmse:1.02606
# [120]	validation_0-rmse:1.02349
# [121]	validation_0-rmse:1.01523
# [122]	validation_0-rmse:1.01003
# [123]	validation_0-rmse:1.00172
# [124]	validation_0-rmse:0.99602
# [125]	validation_0-rmse:0.98345
# [126]	validation_0-rmse:0.97308
# [127]	validation_0-rmse:0.96973
# [128]	validation_0-rmse:0.96664
# [129]	validation_0-rmse:0.96314
# [130]	validation_0-rmse:0.95936
# [131]	validation_0-rmse:0.95345
# [132]	validation_0-rmse:0.95047
# [133]	validation_0-rmse:0.94036
# [134]	validation_0-rmse:0.93632
# [135]	validation_0-rmse:0.92373
# [136]	validation_0-rmse:0.92225
# [137]	validation_0-rmse:0.92105
# [138]	validation_0-rmse:0.91690
# [139]	validation_0-rmse:0.91524
# [140]	validation_0-rmse:0.91141
# [141]	validation_0-rmse:0.89974
# [142]	validation_0-rmse:0.89832
# [143]	validation_0-rmse:0.89250
# [144]	validation_0-rmse:0.88573
# [145]	validation_0-rmse:0.87469
# [146]	validation_0-rmse:0.87350
# [147]	validation_0-rmse:0.86330
# [148]	validation_0-rmse:0.85684
# [149]	validation_0-rmse:0.85146
# [150]	validation_0-rmse:0.84654
# [151]	validation_0-rmse:0.84264
# [152]	validation_0-rmse:0.84044
# [153]	validation_0-rmse:0.83570
# [154]	validation_0-rmse:0.83474
# [155]	validation_0-rmse:0.82678
# [156]	validation_0-rmse:0.82601
# [157]	validation_0-rmse:0.82135
# [158]	validation_0-rmse:0.81158
# [159]	validation_0-rmse:0.80676
# [160]	validation_0-rmse:0.80510
# [161]	validation_0-rmse:0.80437
# [162]	validation_0-rmse:0.80368
# [163]	validation_0-rmse:0.80201
# [164]	validation_0-rmse:0.79536
# [165]	validation_0-rmse:0.79369
# [166]	validation_0-rmse:0.79306
# [167]	validation_0-rmse:0.78675
# [168]	validation_0-rmse:0.78421
# [169]	validation_0-rmse:0.77760
# [170]	validation_0-rmse:0.76954
# [171]	validation_0-rmse:0.76887
# [172]	validation_0-rmse:0.76842
# [173]	validation_0-rmse:0.76656
# [174]	validation_0-rmse:0.76371
# [175]	validation_0-rmse:0.75769
# [176]	validation_0-rmse:0.75484
# [177]	validation_0-rmse:0.75108
# [178]	validation_0-rmse:0.74789
# [179]	validation_0-rmse:0.74749
# [180]	validation_0-rmse:0.74513
# [181]	validation_0-rmse:0.74344
# [182]	validation_0-rmse:0.74153
# [183]	validation_0-rmse:0.73964
# [184]	validation_0-rmse:0.73917
# [185]	validation_0-rmse:0.73878
# [594]	validation_0-rmse:0.40816
# [595]	validation_0-rmse:0.40762
# [596]	validation_0-rmse:0.40747
# [597]	validation_0-rmse:0.40712
# [598]	validation_0-rmse:0.40636
# [599]	validation_0-rmse:0.40634
# [600]	validation_0-rmse:0.40624
# [601]	validation_0-rmse:0.40612
# [602]	validation_0-rmse:0.40597
# [603]	validation_0-rmse:0.40593
# [604]	validation_0-rmse:0.40581
# [605]	validation_0-rmse:0.40578
# [606]	validation_0-rmse:0.40574
# [607]	validation_0-rmse:0.40559
# [608]	validation_0-rmse:0.40559
# [609]	validation_0-rmse:0.40559
# [610]	validation_0-rmse:0.40557
# [611]	validation_0-rmse:0.40508
# [612]	validation_0-rmse:0.40511
# [613]	validation_0-rmse:0.40492
# [614]	validation_0-rmse:0.40483
# [615]	validation_0-rmse:0.40480
# [616]	validation_0-rmse:0.40432
# [617]	validation_0-rmse:0.40431
# [618]	validation_0-rmse:0.40429
# [619]	validation_0-rmse:0.40429
# [620]	validation_0-rmse:0.40413
# [621]	validation_0-rmse:0.40353
# [622]	validation_0-rmse:0.40356
# [623]	validation_0-rmse:0.40354
# [624]	validation_0-rmse:0.40321
# [625]	validation_0-rmse:0.40298
# [626]	validation_0-rmse:0.40297
# [627]	validation_0-rmse:0.40287
# [628]	validation_0-rmse:0.40287
# [629]	validation_0-rmse:0.40281
# [630]	validation_0-rmse:0.40273
# [631]	validation_0-rmse:0.40271
# [632]	validation_0-rmse:0.40270
# [633]	validation_0-rmse:0.40265
# [634]	validation_0-rmse:0.40247
# [635]	validation_0-rmse:0.40224
# [636]	validation_0-rmse:0.40225
# [637]	validation_0-rmse:0.40213
# [638]	validation_0-rmse:0.40193
# [639]	validation_0-rmse:0.40192
# [640]	validation_0-rmse:0.40190
# [641]	validation_0-rmse:0.40191
# [642]	validation_0-rmse:0.40189
# [643]	validation_0-rmse:0.40184
# [644]	validation_0-rmse:0.40184
# [645]	validation_0-rmse:0.40182
# [646]	validation_0-rmse:0.40185
# [647]	validation_0-rmse:0.40155
# [648]	validation_0-rmse:0.40141
# [649]	validation_0-rmse:0.40087
# [650]	validation_0-rmse:0.40087
# [651]	validation_0-rmse:0.40086
# [652]	validation_0-rmse:0.40075
# [653]	validation_0-rmse:0.40061
# [654]	validation_0-rmse:0.40062
# [655]	validation_0-rmse:0.40059
# [656]	validation_0-rmse:0.40041
# [657]	validation_0-rmse:0.40038
# [658]	validation_0-rmse:0.40042
# [659]	validation_0-rmse:0.40030
# [660]	validation_0-rmse:0.40018
# [661]	validation_0-rmse:0.40022
# [662]	validation_0-rmse:0.40020
# [663]	validation_0-rmse:0.40020
# [664]	validation_0-rmse:0.40021
# [665]	validation_0-rmse:0.40017
# [666]	validation_0-rmse:0.40018
# [667]	validation_0-rmse:0.40009
# [668]	validation_0-rmse:0.39991
# [669]	validation_0-rmse:0.39990
# [670]	validation_0-rmse:0.39992
# [671]	validation_0-rmse:0.39993
# [672]	validation_0-rmse:0.39978
# [673]	validation_0-rmse:0.39939
# [674]	validation_0-rmse:0.39937
# [675]	validation_0-rmse:0.39938
# [839]	validation_0-rmse:0.38782
# [840]	validation_0-rmse:0.38771
# [841]	validation_0-rmse:0.38769
# [842]	validation_0-rmse:0.38770
# [843]	validation_0-rmse:0.38771
# [844]	validation_0-rmse:0.38760
# [845]	validation_0-rmse:0.38760
# [846]	validation_0-rmse:0.38759
# [847]	validation_0-rmse:0.38756
# [848]	validation_0-rmse:0.38755
# [849]	validation_0-rmse:0.38723
# [850]	validation_0-rmse:0.38725
# [851]	validation_0-rmse:0.38722
# [852]	validation_0-rmse:0.38720
# [853]	validation_0-rmse:0.38701
# [854]	validation_0-rmse:0.38692
# [855]	validation_0-rmse:0.38693
# [856]	validation_0-rmse:0.38691
# [857]	validation_0-rmse:0.38691
# [858]	validation_0-rmse:0.38692
# [859]	validation_0-rmse:0.38677
# [860]	validation_0-rmse:0.38675
# [861]	validation_0-rmse:0.38655
# [862]	validation_0-rmse:0.38653
# [863]	validation_0-rmse:0.38632
# [864]	validation_0-rmse:0.38631
# [865]	validation_0-rmse:0.38629
# [866]	validation_0-rmse:0.38626
# [867]	validation_0-rmse:0.38628
# [868]	validation_0-rmse:0.38622
# [869]	validation_0-rmse:0.38604
# [870]	validation_0-rmse:0.38606
# [871]	validation_0-rmse:0.38606
# [872]	validation_0-rmse:0.38606
# [873]	validation_0-rmse:0.38600
# [874]	validation_0-rmse:0.38587
# [875]	validation_0-rmse:0.38587
# [876]	validation_0-rmse:0.38575
# [877]	validation_0-rmse:0.38575
# [878]	validation_0-rmse:0.38569
# [879]	validation_0-rmse:0.38564
# [880]	validation_0-rmse:0.38563
# [881]	validation_0-rmse:0.38562
# [882]	validation_0-rmse:0.38564
# [883]	validation_0-rmse:0.38564
# [884]	validation_0-rmse:0.38559
# [885]	validation_0-rmse:0.38558
# [886]	validation_0-rmse:0.38557
# [887]	validation_0-rmse:0.38552
# [888]	validation_0-rmse:0.38552
# [889]	validation_0-rmse:0.38541
# [890]	validation_0-rmse:0.38535
# [891]	validation_0-rmse:0.38538
# [892]	validation_0-rmse:0.38539
# [893]	validation_0-rmse:0.38534
# [894]	validation_0-rmse:0.38519
# [895]	validation_0-rmse:0.38518
# [896]	validation_0-rmse:0.38507
# [897]	validation_0-rmse:0.38502
# [898]	validation_0-rmse:0.38496
# [899]	validation_0-rmse:0.38494
# [900]	validation_0-rmse:0.38486
# [901]	validation_0-rmse:0.38475
# [902]	validation_0-rmse:0.38460
# [903]	validation_0-rmse:0.38457
# [904]	validation_0-rmse:0.38451
# [905]	validation_0-rmse:0.38451
# [906]	validation_0-rmse:0.38443
# [907]	validation_0-rmse:0.38441
# [908]	validation_0-rmse:0.38435
# [909]	validation_0-rmse:0.38427
# [910]	validation_0-rmse:0.38423
# [911]	validation_0-rmse:0.38417
# [912]	validation_0-rmse:0.38417
# [913]	validation_0-rmse:0.38414
# [914]	validation_0-rmse:0.38412
# [915]	validation_0-rmse:0.38414
# [916]	validation_0-rmse:0.38417
# [917]	validation_0-rmse:0.38420
# [918]	validation_0-rmse:0.38400
# [919]	validation_0-rmse:0.38390
# [920]	validation_0-rmse:0.38378
# [921]	validation_0-rmse:0.38379
# [922]	validation_0-rmse:0.38379
# [923]	validation_0-rmse:0.38379
# [924]	validation_0-rmse:0.38372
# [925]	validation_0-rmse:0.38369
# [926]	validation_0-rmse:0.38368
# [927]	validation_0-rmse:0.38355
# [928]	validation_0-rmse:0.38356
# [929]	validation_0-rmse:0.38359
# [930]	validation_0-rmse:0.38359
# [931]	validation_0-rmse:0.38356
# [932]	validation_0-rmse:0.38359
# [933]	validation_0-rmse:0.38357
# [934]	validation_0-rmse:0.38357
# [935]	validation_0-rmse:0.38362
# [936]	validation_0-rmse:0.38360
# [937]	validation_0-rmse:0.38357
# [938]	validation_0-rmse:0.38356
# [939]	validation_0-rmse:0.38352
# [940]	validation_0-rmse:0.38352
# [941]	validation_0-rmse:0.38344
# [942]	validation_0-rmse:0.38347
# [943]	validation_0-rmse:0.38344
# [944]	validation_0-rmse:0.38341
# [945]	validation_0-rmse:0.38340
# [946]	validation_0-rmse:0.38336
# [947]	validation_0-rmse:0.38333
# [948]	validation_0-rmse:0.38336
# [949]	validation_0-rmse:0.38329
# [950]	validation_0-rmse:0.38328
# [951]	validation_0-rmse:0.38310
# [952]	validation_0-rmse:0.38310
# [953]	validation_0-rmse:0.38288
# [954]	validation_0-rmse:0.38289
# [955]	validation_0-rmse:0.38293
# [956]	validation_0-rmse:0.38291
# [957]	validation_0-rmse:0.38288
# [958]	validation_0-rmse:0.38287
# [959]	validation_0-rmse:0.38258
# [960]	validation_0-rmse:0.38244
# [961]	validation_0-rmse:0.38243
# [962]	validation_0-rmse:0.38243
# [963]	validation_0-rmse:0.38244
# [964]	validation_0-rmse:0.38241
# [965]	validation_0-rmse:0.38237
# [966]	validation_0-rmse:0.38237
# [967]	validation_0-rmse:0.38227
# [968]	validation_0-rmse:0.38211
# [969]	validation_0-rmse:0.38206
# [970]	validation_0-rmse:0.38205
# [971]	validation_0-rmse:0.38202
# [972]	validation_0-rmse:0.38203
# [973]	validation_0-rmse:0.38200
# [974]	validation_0-rmse:0.38193
# [975]	validation_0-rmse:0.38190
# [976]	validation_0-rmse:0.38191
# [977]	validation_0-rmse:0.38190
# [978]	validation_0-rmse:0.38190
# [979]	validation_0-rmse:0.38181
# [980]	validation_0-rmse:0.38177
# [981]	validation_0-rmse:0.38175
# [982]	validation_0-rmse:0.38173
# [983]	validation_0-rmse:0.38177
# [984]	validation_0-rmse:0.38175
# [985]	validation_0-rmse:0.38165
# [986]	validation_0-rmse:0.38158
# [987]	validation_0-rmse:0.38156
# [988]	validation_0-rmse:0.38152
# [989]	validation_0-rmse:0.38146
# [990]	validation_0-rmse:0.38145
# [991]	validation_0-rmse:0.38145
# [992]	validation_0-rmse:0.38145
# [993]	validation_0-rmse:0.38143
# [994]	validation_0-rmse:0.38144
# [995]	validation_0-rmse:0.38144
# [996]	validation_0-rmse:0.38142
# [997]	validation_0-rmse:0.38139
# [998]	validation_0-rmse:0.38128
# [999]	validation_0-rmse:0.38104
# [1000]	validation_0-rmse:0.38091
# [1001]	validation_0-rmse:0.38089
# [1080]	validation_0-rmse:0.37826
# [1081]	validation_0-rmse:0.37823
# [1082]	validation_0-rmse:0.37819
# [1083]	validation_0-rmse:0.37811
# [1084]	validation_0-rmse:0.37809
# [1085]	validation_0-rmse:0.37806
# [1086]	validation_0-rmse:0.37790
# [1087]	validation_0-rmse:0.37789
# [1088]	validation_0-rmse:0.37787
# [1089]	validation_0-rmse:0.37785
# [1090]	validation_0-rmse:0.37785
# [1091]	validation_0-rmse:0.37786
# [1092]	validation_0-rmse:0.37788
# [1093]	validation_0-rmse:0.37788
# [1094]	validation_0-rmse:0.37789
# [1095]	validation_0-rmse:0.37791
# [1096]	validation_0-rmse:0.37792
# [1097]	validation_0-rmse:0.37790
# [1098]	validation_0-rmse:0.37788
# [1099]	validation_0-rmse:0.37780
# CPU times: user 1min 55s, sys: 2min 11s, total: 4min 7s
# Wall time: 16.8 s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, enable_categorical=False,
#              eta=0.03425616464106714, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.034256164,
#              max_delta_step=0, max_depth=5, min_child_weight=56, missing=nan,
#              monotone_constraints='()', n_estimators=1100, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=45,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Inference for xgboost 
pred_xgboost = model_xgb.predict(X_test_)
best_rmse_xgb = np.sqrt(mean_squared_error(Y_test_, pred_xgboost) )
best_r2_xgb = r2_score(Y_test_, pred_xgboost) 
print(f"--RMSE perf = {best_rmse_xgb} -- r2 perf = {best_r2_xgb}")
# Out:
# --RMSE perf = 0.3777988808188163 -- r2 perf = 0.9971887292986349

# %% [markdown]
# ## Interpretability: using feature attribution on the test data

# %% [markdown]
# - For Linear Regression, the effect is given by $\beta\odot x$ where $\beta$ is the regression coefficients.
# - For TabSRALinear, the feature attribution vector is $\beta\odot a\odot x$ where $\beta$ is the linear regression coefficients, $a$ the SRA attention weights $\in [0,1]$ and $x$ the input vector.
# - For XGBoost, we will use TreeSHAP https://shap-lrjball.readthedocs.io/en/latest/generated/shap.TreeExplainer.html to get the feature attribution.

# %%
# %%time
attributions_lr = pd.DataFrame(SimpleLR.classifier.weight.data.to('cpu').numpy().ravel()*val_set[:][0].numpy())
attributions_lr.columns = feature_names
attributions_lr['pred'] = pred_tab_lr
attributions_lr['label'] = val_set[:][1].numpy()
# Out:
# CPU times: user 32.9 ms, sys: 84.8 ms, total: 118 ms
# Wall time: 8.1 ms

# %%
# %%time
attributions_tabsra = pd.DataFrame(att*Model.classifier.weight.data.to('cpu').numpy().ravel()*val_set[:][0].numpy())
attributions_tabsra.columns = feature_names
attributions_tabsra['pred'] = pred_tabsra
attributions_tabsra['label'] = val_set[:][1].numpy()
# Out:
# CPU times: user 11.6 ms, sys: 9.57 ms, total: 21.2 ms
# Wall time: 1.4 ms

# %%
# %%time
import shap
explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer(X_test_)
attributions_xgb = pd.DataFrame(shap_values.values)
attributions_xgb.columns = feature_names
attributions_xgb['pred'] = pred_xgboost
attributions_xgb['label'] = val_set[:][1].numpy()
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# CPU times: user 25 s, sys: 1.51 s, total: 26.5 s
# Wall time: 2.19 s

# %%
print(f"LR --RMSE perf = {rmse} -- r2 perf = {r2}")
f, ax = plt.subplots(5, 5, sharey=True,figsize=(15, 15))
for i in range(5):
    for j in range(5):
        ax[i,j].scatter(df_test[f"x{j+1}"], attributions_lr[f"x{i+1}"]) 
        ax[i,j].set_xlabel(f"x_{j+1}",weight = 'bold')
        ax[i,j].set_ylabel(f"contribution x_{i+1}",weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# LR --RMSE perf = 5.042609461402693 -- r2 perf = 0.4991680792159717

# %%
print(f"TabSRALinear --RMSE perf = {rmse_tabsra} -- r2 perf = {r2_tabsra}")
f, ax = plt.subplots(5, 5, sharey=True,figsize=(15, 15))
for i in range(5):
    for j in range(5):
        ax[i,j].scatter(df_test[f"x{j+1}"], attributions_tabsra[f"x{i+1}"]) 
        ax[i,j].set_xlabel(f"x_{j+1}",weight = 'bold')
        ax[i,j].set_ylabel(f"contribution x_{i+1}",weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# TabSRALinear --RMSE perf = 0.37512070997404334 -- r2 perf = 0.9972284455460778

# %%
print(f"XGBoost --RMSE perf = {best_rmse_xgb} -- r2 perf = {best_r2_xgb}")
f, ax = plt.subplots(5, 5, sharey=True,figsize=(15, 15))
for i in range(5):
    for j in range(5):
        ax[i,j].scatter(df_test[f"x{j+1}"], attributions_xgb[f"x{i+1}"]) 
        ax[i,j].set_xlabel(f"x_{j+1}",weight = 'bold')
        ax[i,j].set_ylabel(f"contribution x_{i+1}",weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# XGBoost --RMSE perf = 0.3777988808188163 -- r2 perf = 0.9971887292986349

# %% [markdown]
# ## Identification of important features

# %% [markdown]
# For this example, a perfect model should use only the features $x_1$ and $x_2$, or alternatively, depending on the sign of $x_5$, use the features $x_3$ and $x_4$.
# We restrict our analysis to those data points with $x_5\le 0$. Therefore only $x_1$ and $x_2$ are relevant among $(x_1, x_2, x_3, x_4)$.

# %%
### Add x5
attributions_lr['x5_raw'] = df_test["x5"]
attributions_tabsra['x5_raw'] = df_test["x5"]
attributions_xgb['x5_raw'] = df_test["x5"]

# %%
attributions_lr_tmp = attributions_lr[attributions_lr.x5_raw<0]
attributions_tabsra_tmp = attributions_tabsra[attributions_tabsra.x5_raw<0]
attributions_xgb_tmp = attributions_xgb[attributions_xgb.x5_raw<0]

# %%
### Two first features ('x1','x2') should have index (2,3) ie most important in absolute value
precision_lr = np.argsort(attributions_lr_tmp[['x1','x2','x3','x4']].abs()).apply(lambda x: len(set([2,3]).intersection(set(x[0:2]))),axis=1)
precision_lr.mean()/2
# Out:
# 0.5114666666666666

# %%
precision_tabsra = np.argsort(attributions_tabsra_tmp[['x1','x2','x3','x4']].abs()).apply(lambda x: len(set([2,3]).intersection(set(x[0:2]))),axis=1)
precision_tabsra.mean()/2
# Out:
# 0.9985333333333334

# %%
precision_xgb= np.argsort(attributions_xgb_tmp[['x1','x2','x3','x4']].abs()).apply(lambda x: len(set([2,3]).intersection(set(x[0:2]))),axis=1)
precision_xgb.mean()/2
# Out:
# 0.7570666666666667

# %% [markdown]
# TabSRALinear can identify the two most important features with high precision **99.85%**
