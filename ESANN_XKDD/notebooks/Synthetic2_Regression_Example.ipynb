# %% [markdown]
# # Regression example using TabSRALinear: *Synthetic* 2 dataset
#
#
#    $$y  = x_1^2{1}_{x_1\le 0}$$

# %% [markdown]
# ## Librairies

# %%
import os, sys, time
import numpy as np
import pandas as pd

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import torch 
import torch.nn as nn
import torch.optim as optim

# %%
sys.path.append('../')
from SRAModels import TabSRALinear,LR
from utils import TrainRegressionModel,reset_seed_,Predict, load, save,LinearScaling

# %% [markdown]
# ## Data

# %%
np.random.seed(42)
x1 = np.random.normal(0,1,3*10000)
x2 = np.random.normal(0,1,3*10000)
x3 = np.random.normal(0,1,3*10000)
x4 = np.random.normal(0,1,3*10000)
x5 = np.random.normal(0,1,3*10000)
X = np.concatenate((x1.reshape(-1,1), x2.reshape(-1,1),x3.reshape(-1,1),x4.reshape(-1,1),x5.reshape(-1,1)  ),axis=1)

# %%
odd = (x1**2)*(x1<0)
y_c = 1/(1+np.exp(-odd))
y = np.where(y_c>0.5, 1,0)
X_train_,X_test_,Y_train_,Y_test_ = train_test_split(X,odd,stratify =y , random_state=42)
n_features, n_classes = 5,1
len(Y_train_),len(Y_test_)
# Out:
# (22500, 7500)

# %%
feature_names = ['x1','x2','x3','x4','x5']
df_test = pd.DataFrame(X_test_,columns=feature_names)
df_test['y'] = Y_test_
df_test.head()
# Out:
#          x1        x2        x3        x4        x5         y
# 0  1.511155 -0.955850 -1.886978  0.299307 -0.130079  0.000000
# 1 -1.456938 -0.029552 -1.446098  0.644822 -0.729013  2.122667
# 2 -0.495999  0.133913 -0.695774 -0.171824 -0.371713  0.246015
# 3 -0.682022  0.957036 -0.217657 -0.030306  1.037440  0.465154
# 4  0.018017 -1.448417 -0.264760  0.466237 -1.770392  0.000000

# %%
plt.scatter(x1, odd, c = y) #color[y]
plt.xlabel('x1')
plt.ylabel('target')
plt.show()

# %% [markdown]
# ## Model: LR (Linear Regression)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
train_set = torch.utils.data.TensorDataset(torch.Tensor(X_train_), torch.Tensor(Y_train_))
val_set = torch.utils.data.TensorDataset(torch.Tensor(X_test_), torch.Tensor(Y_test_))

# %%
## function to build the model
def buildLR(static_params):
    Model = LR(dim_input = static_params['dim_input'],
                   dim_output = static_params['dim_output'],
                   bias = static_params['bias'],
                   for_classif=False
                  )
    return Model

# %%
static_params_LR = {'dim_input':n_features, 'dim_output':n_classes, 'bias':True}

# %%
# %%time
reset_seed_(45)
SimpleLR = buildLR(static_params_LR)
save_model_dir= f'LR_Synthetic2'
SimpleLR = TrainRegressionModel(SimpleLR, 
                   train_set = train_set,
                   test_set=val_set,
                   save_path=save_model_dir,
                   device = device,
                   epochs= 150,
                   batch_size = 256,
                   lr = 0.5*1e-2,
                   eval_every = 5,
                   weight_decay = 0.0,
                   verbose=1,
                   load_best_eval=True
                   )
# Out:
# epoch = 0--rmse perf = 0.7905448079109192
# epoch = 5--rmse perf = 0.7613922357559204
# epoch = 10--rmse perf = 0.7615777850151062
# epoch = 15--rmse perf = 0.7608364820480347
# epoch = 20--rmse perf = 0.7608946561813354
# epoch = 25--rmse perf = 0.7611759901046753
# epoch = 30--rmse perf = 0.761989951133728
# epoch = 35--rmse perf = 0.7614490389823914
# epoch = 40--rmse perf = 0.7614206671714783
# epoch = 45--rmse perf = 0.7610563039779663
# epoch = 50--rmse perf = 0.7607844471931458
# epoch = 55--rmse perf = 0.7614076137542725
# epoch = 60--rmse perf = 0.7618029713630676
# epoch = 65--rmse perf = 0.7617277503013611
# epoch = 70--rmse perf = 0.7611564993858337
# epoch = 75--rmse perf = 0.7610608339309692
# epoch = 80--rmse perf = 0.761361837387085
# epoch = 85--rmse perf = 0.761650800704956
# epoch = 90--rmse perf = 0.761552095413208
# epoch = 95--rmse perf = 0.7611547708511353
# epoch = 100--rmse perf = 0.7632535099983215
# epoch = 105--rmse perf = 0.7610113620758057
# epoch = 110--rmse perf = 0.7615567445755005
# epoch = 115--rmse perf = 0.7612616419792175
# epoch = 120--rmse perf = 0.7606927752494812
# epoch = 125--rmse perf = 0.7614925503730774
# epoch = 130--rmse perf = 0.7617823481559753
# epoch = 135--rmse perf = 0.7605895400047302
# epoch = 140--rmse perf = 0.7608904838562012
# epoch = 145--rmse perf = 0.7610019445419312
# CPU times: user 21.9 s, sys: 659 ms, total: 22.5 s
# Wall time: 21.3 s

# %%
pred_tab_lr = Predict(SimpleLR,val_set[:][0],device=device)
rmse = np.sqrt(mean_squared_error(Y_test_, pred_tab_lr))
r2 = r2_score(Y_test_, pred_tab_lr) 
print(f"--RMSE perf = {rmse} -- r2 perf = {r2}")
# Out:
# --RMSE perf = 0.7605895654807479 -- r2 perf = 0.5038074852086862

# %% [markdown]
# ## Model: TabSRALinear

# %%
## function to build the model
def buildTabSRA(config_opt,static_params):
    Model = TabSRALinear(dim_input = static_params['dim_input'],
                   dim_output = static_params['dim_output'],
                   dim_head = config_opt['dim_head'],
                   get_attention = static_params['get_attention'],
                   dropout_rate = config_opt['dropout_rate'],
                   activation = static_params['activation'],
                   bias = static_params['bias'],
                   s =  LinearScaling(scale = config_opt['dim_head']**-0.5),
                   for_classif=False
                  )
    return Model

# %%
## The hyperparameters are already optimized (using optuna) 
config_opt = {'lr': 1e-2, 'dropout_rate': 0.0, 'dim_head': 8, 'epochs': 150, 'weight_decay': 1e-6, 'batch_size': 768}
static_params = {'dim_input':n_features, 'dim_output':n_classes,'get_attention':True, 'activation':nn.ReLU(), 'bias':True}

# %%
# %%time
reset_seed_(42)
Model = buildTabSRA(config_opt,static_params)
save_model_dir= f'TabSRALinear_Synthetic2'
Model = TrainRegressionModel(Model, 
                   train_set = train_set,
                   test_set=val_set,
                   save_path=save_model_dir,
                   device = device,
                   epochs= config_opt['epochs'],
                   batch_size = config_opt['batch_size'],
                   lr = config_opt['lr'],
                   eval_every = 5,
                   weight_decay = config_opt['weight_decay'],
                   verbose=1,
                   load_best_eval=True
                   )
# Out:
# epoch = 0--rmse perf = 0.879551112651825
# epoch = 5--rmse perf = 0.2770652174949646
# epoch = 10--rmse perf = 0.17170201241970062
# epoch = 15--rmse perf = 0.12487591058015823
# epoch = 20--rmse perf = 0.09815322607755661
# epoch = 25--rmse perf = 0.08277104794979095
# epoch = 30--rmse perf = 0.0708114355802536
# epoch = 35--rmse perf = 0.06270794570446014
# epoch = 40--rmse perf = 0.05509037524461746
# epoch = 45--rmse perf = 0.046343158930540085
# epoch = 50--rmse perf = 0.044442445039749146
# epoch = 55--rmse perf = 0.03780115768313408
# epoch = 60--rmse perf = 0.03490132838487625
# epoch = 65--rmse perf = 0.032956115901470184
# epoch = 70--rmse perf = 0.03010094165802002
# epoch = 75--rmse perf = 0.027525506913661957
# epoch = 80--rmse perf = 0.029259437695145607
# epoch = 85--rmse perf = 0.026883944869041443
# epoch = 90--rmse perf = 0.03328671306371689
# epoch = 95--rmse perf = 0.023508822545409203
# epoch = 100--rmse perf = 0.025713074952363968
# epoch = 105--rmse perf = 0.02486792393028736
# epoch = 110--rmse perf = 0.02454650215804577
# epoch = 115--rmse perf = 0.02593662217259407
# epoch = 120--rmse perf = 0.023023201152682304
# epoch = 125--rmse perf = 0.024343259632587433
# epoch = 130--rmse perf = 0.022666247561573982
# epoch = 135--rmse perf = 0.023147229105234146
# epoch = 140--rmse perf = 0.02265353687107563
# epoch = 145--rmse perf = 0.0196225643157959
# CPU times: user 24.6 s, sys: 135 ms, total: 24.7 s
# Wall time: 24.7 s

# %%
# Inference on the test set. the Predict function will return the ouptut scores and the attention weights as Model.get_attention is True
att,pred_tabsra = Predict(Model,val_set[:][0],device=device)

rmse_tabsra = np.sqrt(mean_squared_error(Y_test_, pred_tabsra))
r2_tabsra = r2_score(Y_test_, pred_tabsra) 
print(f"--RMSE perf = {rmse_tabsra} -- r2 perf = {r2_tabsra}")
# Out:
# --RMSE perf = 0.01962256630061539 -- r2 perf = 0.9996697361093607

# %%
Model.classifier.weight
# Out:
# Parameter containing:
# tensor([[-3.4950, -1.6255,  1.5929, -1.6117,  1.7705]], device='cuda:0',
#        requires_grad=True)

# %% [markdown]
# ## Model: XGBoost

# %%
from xgboost import XGBRegressor
# Out:
# /home/kodjo/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
def buildXGBoost(config_opt,static_params):
    config_opt.update(static_params)
    model_xgb = XGBRegressor(**config_opt)
    return model_xgb

# %%
### These parameters are optimized using 30 trials with optuna (bayesian optimization)
config_opt_xgb = {
              'eta': 0.03425616464106714,
              'max_depth': 5,
              'colsample_bytree': 0.8,
              'subsample': 0.7,
              'n_estimators': 910,
              'min_child_weight':56

              }
static_params_xgb = {
                 'random_state':45,
                 'n_jobs': -1,
}

# %%
# %%time
model_xgb = buildXGBoost(config_opt=config_opt_xgb,static_params=static_params_xgb)
eval_set = [(X_test_, Y_test_)]
model_xgb.fit(X_train_, Y_train_, eval_metric=['rmse'], eval_set=eval_set, verbose=1)
# Out:
# [0]	validation_0-rmse:1.04373
# [1]	validation_0-rmse:1.00851
# [2]	validation_0-rmse:0.97449
# [3]	validation_0-rmse:0.94185
# [4]	validation_0-rmse:0.91031
# [5]	validation_0-rmse:0.87974
# [6]	validation_0-rmse:0.87973
# [7]	validation_0-rmse:0.85025
# [8]	validation_0-rmse:0.82183
# [9]	validation_0-rmse:0.82183
# [91]	validation_0-rmse:0.13136
# [92]	validation_0-rmse:0.12920
# [93]	validation_0-rmse:0.12706
# [94]	validation_0-rmse:0.12523
# [95]	validation_0-rmse:0.12331
# [96]	validation_0-rmse:0.12141
# [97]	validation_0-rmse:0.11968
# [98]	validation_0-rmse:0.11969
# [99]	validation_0-rmse:0.11804
# [100]	validation_0-rmse:0.11646
# [101]	validation_0-rmse:0.11496
# [102]	validation_0-rmse:0.11356
# [103]	validation_0-rmse:0.11214
# [104]	validation_0-rmse:0.11087
# [105]	validation_0-rmse:0.10968
# [106]	validation_0-rmse:0.10864
# [107]	validation_0-rmse:0.10761
# [108]	validation_0-rmse:0.10658
# [109]	validation_0-rmse:0.10659
# [110]	validation_0-rmse:0.10571
# [111]	validation_0-rmse:0.10476
# [112]	validation_0-rmse:0.10392
# [113]	validation_0-rmse:0.10305
# [114]	validation_0-rmse:0.10237
# [115]	validation_0-rmse:0.10237
# [116]	validation_0-rmse:0.10164
# [117]	validation_0-rmse:0.10102
# [118]	validation_0-rmse:0.10102
# [119]	validation_0-rmse:0.10102
# [120]	validation_0-rmse:0.10042
# [121]	validation_0-rmse:0.09976
# [122]	validation_0-rmse:0.09917
# [123]	validation_0-rmse:0.09917
# [124]	validation_0-rmse:0.09918
# [125]	validation_0-rmse:0.09871
# [126]	validation_0-rmse:0.09832
# [127]	validation_0-rmse:0.09787
# [128]	validation_0-rmse:0.09742
# [129]	validation_0-rmse:0.09702
# [130]	validation_0-rmse:0.09702
# [131]	validation_0-rmse:0.09661
# [132]	validation_0-rmse:0.09625
# [133]	validation_0-rmse:0.09593
# [134]	validation_0-rmse:0.09558
# [135]	validation_0-rmse:0.09530
# [136]	validation_0-rmse:0.09500
# [137]	validation_0-rmse:0.09474
# [138]	validation_0-rmse:0.09451
# [139]	validation_0-rmse:0.09427
# [140]	validation_0-rmse:0.09417
# [141]	validation_0-rmse:0.09396
# [142]	validation_0-rmse:0.09378
# [143]	validation_0-rmse:0.09358
# [144]	validation_0-rmse:0.09342
# [145]	validation_0-rmse:0.09326
# [146]	validation_0-rmse:0.09317
# [147]	validation_0-rmse:0.09308
# [148]	validation_0-rmse:0.09294
# [149]	validation_0-rmse:0.09280
# [150]	validation_0-rmse:0.09269
# [151]	validation_0-rmse:0.09262
# [152]	validation_0-rmse:0.09253
# [153]	validation_0-rmse:0.09253
# [154]	validation_0-rmse:0.09243
# [155]	validation_0-rmse:0.09239
# [156]	validation_0-rmse:0.09231
# [157]	validation_0-rmse:0.09216
# [158]	validation_0-rmse:0.09216
# [159]	validation_0-rmse:0.09206
# [160]	validation_0-rmse:0.09198
# [161]	validation_0-rmse:0.09191
# [162]	validation_0-rmse:0.09185
# [163]	validation_0-rmse:0.09179
# [164]	validation_0-rmse:0.09172
# [165]	validation_0-rmse:0.09172
# [166]	validation_0-rmse:0.09162
# [167]	validation_0-rmse:0.09162
# [168]	validation_0-rmse:0.09162
# [169]	validation_0-rmse:0.09160
# [170]	validation_0-rmse:0.09154
# [171]	validation_0-rmse:0.09148
# [415]	validation_0-rmse:0.09026
# [416]	validation_0-rmse:0.09026
# [417]	validation_0-rmse:0.09023
# [418]	validation_0-rmse:0.09023
# [419]	validation_0-rmse:0.09023
# [420]	validation_0-rmse:0.09023
# [421]	validation_0-rmse:0.09023
# [422]	validation_0-rmse:0.09023
# [423]	validation_0-rmse:0.09023
# [424]	validation_0-rmse:0.09023
# [425]	validation_0-rmse:0.09023
# [426]	validation_0-rmse:0.09023
# [427]	validation_0-rmse:0.09023
# [428]	validation_0-rmse:0.09023
# [429]	validation_0-rmse:0.09023
# [430]	validation_0-rmse:0.09023
# [431]	validation_0-rmse:0.09024
# [432]	validation_0-rmse:0.09024
# [433]	validation_0-rmse:0.09024
# [434]	validation_0-rmse:0.09025
# [435]	validation_0-rmse:0.09025
# [436]	validation_0-rmse:0.09025
# [437]	validation_0-rmse:0.09025
# [438]	validation_0-rmse:0.09025
# [439]	validation_0-rmse:0.09024
# [440]	validation_0-rmse:0.09024
# [441]	validation_0-rmse:0.09024
# [442]	validation_0-rmse:0.09024
# [443]	validation_0-rmse:0.09025
# [444]	validation_0-rmse:0.09025
# [445]	validation_0-rmse:0.09025
# [446]	validation_0-rmse:0.09025
# [447]	validation_0-rmse:0.09025
# [448]	validation_0-rmse:0.09025
# [449]	validation_0-rmse:0.09025
# [450]	validation_0-rmse:0.09025
# [451]	validation_0-rmse:0.09025
# [452]	validation_0-rmse:0.09025
# [453]	validation_0-rmse:0.09025
# [454]	validation_0-rmse:0.09025
# [455]	validation_0-rmse:0.09024
# [456]	validation_0-rmse:0.09024
# [457]	validation_0-rmse:0.09025
# [458]	validation_0-rmse:0.09024
# [459]	validation_0-rmse:0.09023
# [460]	validation_0-rmse:0.09024
# [461]	validation_0-rmse:0.09023
# [462]	validation_0-rmse:0.09023
# [463]	validation_0-rmse:0.09023
# [464]	validation_0-rmse:0.09023
# [465]	validation_0-rmse:0.09023
# [466]	validation_0-rmse:0.09022
# [467]	validation_0-rmse:0.09023
# [468]	validation_0-rmse:0.09023
# [469]	validation_0-rmse:0.09023
# [470]	validation_0-rmse:0.09023
# [471]	validation_0-rmse:0.09022
# [472]	validation_0-rmse:0.09022
# [473]	validation_0-rmse:0.09022
# [474]	validation_0-rmse:0.09022
# [475]	validation_0-rmse:0.09022
# [476]	validation_0-rmse:0.09022
# [477]	validation_0-rmse:0.09023
# [478]	validation_0-rmse:0.09022
# [479]	validation_0-rmse:0.09023
# [480]	validation_0-rmse:0.09023
# [481]	validation_0-rmse:0.09023
# [482]	validation_0-rmse:0.09023
# [483]	validation_0-rmse:0.09023
# [484]	validation_0-rmse:0.09023
# [485]	validation_0-rmse:0.09023
# [486]	validation_0-rmse:0.09024
# [487]	validation_0-rmse:0.09023
# [488]	validation_0-rmse:0.09024
# [489]	validation_0-rmse:0.09023
# [490]	validation_0-rmse:0.09022
# [491]	validation_0-rmse:0.09022
# [492]	validation_0-rmse:0.09022
# [493]	validation_0-rmse:0.09021
# [494]	validation_0-rmse:0.09022
# [495]	validation_0-rmse:0.09021
# [658]	validation_0-rmse:0.09010
# [659]	validation_0-rmse:0.09010
# [660]	validation_0-rmse:0.09010
# [661]	validation_0-rmse:0.09009
# [662]	validation_0-rmse:0.09009
# [663]	validation_0-rmse:0.09009
# [664]	validation_0-rmse:0.09009
# [665]	validation_0-rmse:0.09009
# [666]	validation_0-rmse:0.09009
# [667]	validation_0-rmse:0.09009
# [668]	validation_0-rmse:0.09009
# [669]	validation_0-rmse:0.09009
# [670]	validation_0-rmse:0.09009
# [671]	validation_0-rmse:0.09009
# [672]	validation_0-rmse:0.09009
# [673]	validation_0-rmse:0.09009
# [674]	validation_0-rmse:0.09010
# [675]	validation_0-rmse:0.09010
# [676]	validation_0-rmse:0.09010
# [677]	validation_0-rmse:0.09010
# [678]	validation_0-rmse:0.09010
# [679]	validation_0-rmse:0.09010
# [680]	validation_0-rmse:0.09010
# [681]	validation_0-rmse:0.09010
# [682]	validation_0-rmse:0.09010
# [683]	validation_0-rmse:0.09011
# [684]	validation_0-rmse:0.09011
# [685]	validation_0-rmse:0.09010
# [686]	validation_0-rmse:0.09011
# [687]	validation_0-rmse:0.09010
# [688]	validation_0-rmse:0.09010
# [689]	validation_0-rmse:0.09010
# [690]	validation_0-rmse:0.09010
# [691]	validation_0-rmse:0.09009
# [692]	validation_0-rmse:0.09009
# [693]	validation_0-rmse:0.09010
# [694]	validation_0-rmse:0.09010
# [695]	validation_0-rmse:0.09010
# [696]	validation_0-rmse:0.09010
# [697]	validation_0-rmse:0.09011
# [698]	validation_0-rmse:0.09009
# [699]	validation_0-rmse:0.09010
# [700]	validation_0-rmse:0.09010
# [701]	validation_0-rmse:0.09011
# [702]	validation_0-rmse:0.09011
# [703]	validation_0-rmse:0.09012
# [704]	validation_0-rmse:0.09011
# [705]	validation_0-rmse:0.09010
# [706]	validation_0-rmse:0.09011
# [707]	validation_0-rmse:0.09013
# [708]	validation_0-rmse:0.09012
# [709]	validation_0-rmse:0.09013
# [710]	validation_0-rmse:0.09013
# [711]	validation_0-rmse:0.09012
# [712]	validation_0-rmse:0.09011
# [713]	validation_0-rmse:0.09012
# [714]	validation_0-rmse:0.09012
# [715]	validation_0-rmse:0.09012
# [716]	validation_0-rmse:0.09013
# [717]	validation_0-rmse:0.09014
# [718]	validation_0-rmse:0.09011
# [719]	validation_0-rmse:0.09012
# [720]	validation_0-rmse:0.09012
# [721]	validation_0-rmse:0.09010
# [722]	validation_0-rmse:0.09009
# [723]	validation_0-rmse:0.09010
# [724]	validation_0-rmse:0.09010
# [725]	validation_0-rmse:0.09010
# [726]	validation_0-rmse:0.09011
# [727]	validation_0-rmse:0.09011
# [728]	validation_0-rmse:0.09012
# [729]	validation_0-rmse:0.09011
# [730]	validation_0-rmse:0.09011
# [731]	validation_0-rmse:0.09012
# [732]	validation_0-rmse:0.09012
# [733]	validation_0-rmse:0.09012
# [734]	validation_0-rmse:0.09012
# [735]	validation_0-rmse:0.09013
# [736]	validation_0-rmse:0.09014
# [737]	validation_0-rmse:0.09014
# [738]	validation_0-rmse:0.09013
# [739]	validation_0-rmse:0.09012
# [740]	validation_0-rmse:0.09012
# [741]	validation_0-rmse:0.09011
# [742]	validation_0-rmse:0.09011
# [743]	validation_0-rmse:0.09011
# [744]	validation_0-rmse:0.09010
# [745]	validation_0-rmse:0.09010
# [746]	validation_0-rmse:0.09011
# [747]	validation_0-rmse:0.09012
# [748]	validation_0-rmse:0.09010
# [749]	validation_0-rmse:0.09010
# [750]	validation_0-rmse:0.09009
# [751]	validation_0-rmse:0.09010
# [752]	validation_0-rmse:0.09009
# [753]	validation_0-rmse:0.09008
# [754]	validation_0-rmse:0.09008
# [755]	validation_0-rmse:0.09007
# [756]	validation_0-rmse:0.09007
# [757]	validation_0-rmse:0.09007
# [758]	validation_0-rmse:0.09007
# [759]	validation_0-rmse:0.09008
# [760]	validation_0-rmse:0.09008
# [761]	validation_0-rmse:0.09008
# [762]	validation_0-rmse:0.09009
# [763]	validation_0-rmse:0.09008
# [764]	validation_0-rmse:0.09009
# [765]	validation_0-rmse:0.09008
# [766]	validation_0-rmse:0.09008
# [767]	validation_0-rmse:0.09008
# [768]	validation_0-rmse:0.09007
# [769]	validation_0-rmse:0.09008
# [770]	validation_0-rmse:0.09007
# [771]	validation_0-rmse:0.09007
# [772]	validation_0-rmse:0.09007
# [773]	validation_0-rmse:0.09007
# [774]	validation_0-rmse:0.09007
# [775]	validation_0-rmse:0.09007
# [776]	validation_0-rmse:0.09007
# [777]	validation_0-rmse:0.09007
# [778]	validation_0-rmse:0.09007
# [779]	validation_0-rmse:0.09007
# [780]	validation_0-rmse:0.09007
# [781]	validation_0-rmse:0.09007
# [782]	validation_0-rmse:0.09007
# [783]	validation_0-rmse:0.09006
# [784]	validation_0-rmse:0.09006
# [785]	validation_0-rmse:0.09006
# [786]	validation_0-rmse:0.09006
# [787]	validation_0-rmse:0.09006
# [788]	validation_0-rmse:0.09005
# [789]	validation_0-rmse:0.09006
# [790]	validation_0-rmse:0.09007
# [791]	validation_0-rmse:0.09006
# [792]	validation_0-rmse:0.09006
# [793]	validation_0-rmse:0.09006
# [794]	validation_0-rmse:0.09006
# [795]	validation_0-rmse:0.09007
# [796]	validation_0-rmse:0.09006
# [797]	validation_0-rmse:0.09006
# [798]	validation_0-rmse:0.09006
# [799]	validation_0-rmse:0.09005
# [800]	validation_0-rmse:0.09005
# [801]	validation_0-rmse:0.09005
# [802]	validation_0-rmse:0.09005
# [803]	validation_0-rmse:0.09005
# [804]	validation_0-rmse:0.09005
# [805]	validation_0-rmse:0.09006
# [806]	validation_0-rmse:0.09006
# [807]	validation_0-rmse:0.09007
# [808]	validation_0-rmse:0.09007
# [809]	validation_0-rmse:0.09008
# [810]	validation_0-rmse:0.09008
# [811]	validation_0-rmse:0.09008
# [812]	validation_0-rmse:0.09007
# [813]	validation_0-rmse:0.09008
# [814]	validation_0-rmse:0.09008
# [815]	validation_0-rmse:0.09008
# [816]	validation_0-rmse:0.09008
# [817]	validation_0-rmse:0.09008
# [818]	validation_0-rmse:0.09008
# [819]	validation_0-rmse:0.09009
# [820]	validation_0-rmse:0.09009
# [821]	validation_0-rmse:0.09008
# [822]	validation_0-rmse:0.09008
# [823]	validation_0-rmse:0.09008
# [824]	validation_0-rmse:0.09007
# [825]	validation_0-rmse:0.09007
# [826]	validation_0-rmse:0.09007
# [827]	validation_0-rmse:0.09007
# [828]	validation_0-rmse:0.09007
# [829]	validation_0-rmse:0.09007
# [830]	validation_0-rmse:0.09007
# [831]	validation_0-rmse:0.09007
# [832]	validation_0-rmse:0.09007
# [833]	validation_0-rmse:0.09007
# [834]	validation_0-rmse:0.09007
# [835]	validation_0-rmse:0.09007
# [836]	validation_0-rmse:0.09007
# [837]	validation_0-rmse:0.09007
# [838]	validation_0-rmse:0.09008
# [839]	validation_0-rmse:0.09007
# [840]	validation_0-rmse:0.09008
# [841]	validation_0-rmse:0.09008
# [842]	validation_0-rmse:0.09008
# [843]	validation_0-rmse:0.09008
# [844]	validation_0-rmse:0.09008
# [845]	validation_0-rmse:0.09008
# [846]	validation_0-rmse:0.09009
# [847]	validation_0-rmse:0.09009
# [848]	validation_0-rmse:0.09009
# [849]	validation_0-rmse:0.09009
# [850]	validation_0-rmse:0.09010
# [851]	validation_0-rmse:0.09010
# [852]	validation_0-rmse:0.09009
# [853]	validation_0-rmse:0.09009
# [854]	validation_0-rmse:0.09009
# [855]	validation_0-rmse:0.09009
# [856]	validation_0-rmse:0.09009
# [857]	validation_0-rmse:0.09009
# [858]	validation_0-rmse:0.09009
# [859]	validation_0-rmse:0.09008
# [860]	validation_0-rmse:0.09007
# [861]	validation_0-rmse:0.09004
# [862]	validation_0-rmse:0.09004
# [863]	validation_0-rmse:0.09004
# [864]	validation_0-rmse:0.09001
# [865]	validation_0-rmse:0.09001
# [866]	validation_0-rmse:0.09001
# [867]	validation_0-rmse:0.09001
# [868]	validation_0-rmse:0.09001
# [869]	validation_0-rmse:0.09001
# [870]	validation_0-rmse:0.09002
# [871]	validation_0-rmse:0.09002
# [872]	validation_0-rmse:0.09001
# [873]	validation_0-rmse:0.09001
# [874]	validation_0-rmse:0.09001
# [875]	validation_0-rmse:0.09001
# [876]	validation_0-rmse:0.09001
# [877]	validation_0-rmse:0.09001
# [878]	validation_0-rmse:0.09001
# [879]	validation_0-rmse:0.09001
# [880]	validation_0-rmse:0.09000
# [881]	validation_0-rmse:0.09000
# [882]	validation_0-rmse:0.09001
# [883]	validation_0-rmse:0.09001
# [884]	validation_0-rmse:0.09001
# [885]	validation_0-rmse:0.09001
# [886]	validation_0-rmse:0.09001
# [887]	validation_0-rmse:0.09001
# [888]	validation_0-rmse:0.09001
# [889]	validation_0-rmse:0.09001
# [890]	validation_0-rmse:0.09000
# [891]	validation_0-rmse:0.09000
# [892]	validation_0-rmse:0.09000
# [893]	validation_0-rmse:0.09000
# [894]	validation_0-rmse:0.09000
# [895]	validation_0-rmse:0.09000
# [896]	validation_0-rmse:0.09000
# [897]	validation_0-rmse:0.09000
# [898]	validation_0-rmse:0.08999
# [899]	validation_0-rmse:0.09000
# [900]	validation_0-rmse:0.09000
# [901]	validation_0-rmse:0.09000
# [902]	validation_0-rmse:0.09000
# [903]	validation_0-rmse:0.09000
# [904]	validation_0-rmse:0.08999
# [905]	validation_0-rmse:0.09000
# [906]	validation_0-rmse:0.09000
# [907]	validation_0-rmse:0.09000
# [908]	validation_0-rmse:0.08999
# [909]	validation_0-rmse:0.09000
# CPU times: user 1min 40s, sys: 1min 58s, total: 3min 39s
# Wall time: 15.5 s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, enable_categorical=False,
#              eta=0.03425616464106714, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.034256164,
#              max_delta_step=0, max_depth=5, min_child_weight=56, missing=nan,
#              monotone_constraints='()', n_estimators=910, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=45,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.7,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# Inference for xgboost 
pred_xgboost = model_xgb.predict(X_test_)
best_rmse_xgb = np.sqrt(mean_squared_error(Y_test_, pred_xgboost) )
best_r2_xgb = r2_score(Y_test_, pred_xgboost) 
print(f"--RMSE perf = {best_rmse_xgb} -- r2 perf = {best_r2_xgb}")
# Out:
# --RMSE perf = 0.08999699917470588 -- r2 perf = 0.9930528681744824

# %% [markdown]
# ## Interpretability: using feature attribution on the test data

# %% [markdown]
# - For Linear Regression, the effect is given by $\beta\odot x$ where $\beta$ is the regression coefficients.
# - For TabSRALinear, the feature attribution vector is $\beta\odot a\odot x$ where $\beta$ is the linear regression coefficients, $a$ the SRA attention weights $\in [0,1]$ and $x$ the input vector.
# - For XGBoost, we will use TreeSHAP https://shap-lrjball.readthedocs.io/en/latest/generated/shap.TreeExplainer.html to get the feature attribution.

# %%
# %%time
attributions_lr = pd.DataFrame(SimpleLR.classifier.weight.data.to('cpu').numpy().ravel()*val_set[:][0].numpy())
attributions_lr.columns = feature_names
attributions_lr['pred'] = pred_tab_lr
attributions_lr['label'] = val_set[:][1].numpy()
# Out:
# CPU times: user 13.2 ms, sys: 45.1 ms, total: 58.3 ms
# Wall time: 3.97 ms

# %%
# %%time
attributions_tabsra = pd.DataFrame(att*Model.classifier.weight.data.to('cpu').numpy().ravel()*val_set[:][0].numpy())
attributions_tabsra.columns = feature_names
attributions_tabsra['pred'] = pred_tabsra
attributions_tabsra['label'] = val_set[:][1].numpy()
# Out:
# CPU times: user 0 ns, sys: 22.3 ms, total: 22.3 ms
# Wall time: 1.69 ms

# %%
# %%time
import shap
explainer = shap.TreeExplainer(model_xgb)
shap_values = explainer(X_test_)
attributions_xgb = pd.DataFrame(shap_values.values)
attributions_xgb.columns = feature_names
attributions_xgb['pred'] = pred_xgboost
attributions_xgb['label'] = val_set[:][1].numpy()
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# CPU times: user 17.7 s, sys: 1.73 s, total: 19.5 s
# Wall time: 1.65 s

# %%
print(f"LR --RMSE perf = {rmse} -- r2 perf = {r2}")
f, ax = plt.subplots(5, 5, sharey=True,figsize=(15, 15))
for i in range(5):
    for j in range(5):
        ax[i,j].scatter(df_test[f"x{j+1}"], attributions_lr[f"x{i+1}"]) 
        ax[i,j].set_xlabel(f"x_{j+1}",weight = 'bold')
        ax[i,j].set_ylabel(f"contribution x_{i+1}",weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# LR --RMSE perf = 0.7605895654807479 -- r2 perf = 0.5038074852086862

# %%
print(f"TabSRALinear --RMSE perf = {rmse_tabsra} -- r2 perf = {r2_tabsra}")
f, ax = plt.subplots(5, 5, sharey=True,figsize=(15, 15))
for i in range(5):
    for j in range(5):
        ax[i,j].scatter(df_test[f"x{j+1}"], attributions_tabsra[f"x{i+1}"]) 
        ax[i,j].set_xlabel(f"x_{j+1}",weight = 'bold')
        ax[i,j].set_ylabel(f"contribution x_{i+1}",weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# TabSRALinear --RMSE perf = 0.01962256630061539 -- r2 perf = 0.9996697361093607

# %%
print(f"XGBoost --RMSE perf = {best_rmse_xgb} -- r2 perf = {best_r2_xgb}")
f, ax = plt.subplots(5, 5, sharey=True,figsize=(15, 15))
for i in range(5):
    for j in range(5):
        ax[i,j].scatter(df_test[f"x{j+1}"], attributions_xgb[f"x{i+1}"]) 
        ax[i,j].set_xlabel(f"x_{j+1}",weight = 'bold')
        ax[i,j].set_ylabel(f"contribution x_{i+1}",weight = 'bold')
plt.tight_layout()
plt.show()
# Out:
# XGBoost --RMSE perf = 0.08999699917470588 -- r2 perf = 0.9930528681744824

# %% [markdown]
# ## Identification of important features

# %% [markdown]
# We consider in the test set observations where $x_1 \le 0$  hence only $x_1$ should
# have nonzero importance

# %%
### Add x5
attributions_lr['x1_raw'] = df_test["x1"]
attributions_tabsra['x1_raw'] = df_test["x1"]
attributions_xgb['x1_raw'] = df_test["x1"]

# %%
attributions_lr_tmp = attributions_lr[attributions_lr.x1_raw<0]
attributions_tabsra_tmp = attributions_tabsra[attributions_tabsra.x1_raw<0]
attributions_xgb_tmp = attributions_xgb[attributions_xgb.x1_raw<0]

# %%
attributions_tabsra_tmp.head()
# Out:
#          x1        x2            x3            x4            x5      pred  \
# 1  2.114470  0.000248 -1.849172e-06 -1.216914e-05 -2.781658e-05  2.117475
# 2  0.241988 -0.000063 -1.551178e-06  1.660322e-07 -6.425068e-06  0.244716
# 3  0.468904 -0.001127 -1.863675e-06  4.154496e-08  1.299657e-04  0.470704
# 6  2.850250  0.016016 -8.028050e-06 -1.052741e-05  1.019692e-03  2.870067
# 8  0.015381  0.000003 -7.486400e-08  3.744449e-07 -7.102748e-07  0.018183
#
#       label    x1_raw
# 1  2.122667 -1.456938
# 2  0.246015 -0.495999
# 3  0.465154 -0.682022
# 6  2.877489 -1.696316
# 8  0.011923 -0.109193

# %%
precision_lr = np.argsort(attributions_lr_tmp[['x1','x2','x3','x4','x5']].abs()).apply(lambda x: len(set([0]).intersection(set(x[4:5]))),axis=1)
precision_lr.mean()
# Out:
# 0.9911835426128773

# %%
precision_tabsra = np.argsort(attributions_tabsra_tmp[['x1','x2','x3','x4','x5']].abs()).apply(lambda x: len(set([0]).intersection(set(x[4:5]))),axis=1)
precision_tabsra.mean()
# Out:
# 0.9997328346246327

# %%
precision_xgb= np.argsort(attributions_xgb_tmp[['x1','x2','x3','x4','x5']].abs()).apply(lambda x: len(set([0]).intersection(set(x[4:5]))),axis=1)
precision_xgb.mean()
# Out:
# 0.9970611808709591
